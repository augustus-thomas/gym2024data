# %%
#Import data analysis python modules
import pandas as pd
import numpy as np

data_df = pd.read_csv("../../cleandata/data_2022_2023.csv")
men_df = data_df[data_df["Gender"] == "m"]
women_df = data_df[data_df["Gender"] == "w"]
men_df.head()
# Out:
#   LastName          FirstName Gender Country            Date  \
# 0      AAS            Fredrik      m     NOR  23-26 Feb 2023
# 1      AAS            Fredrik      m     NOR  23-26 Feb 2023
# 2      AAS  Fredrik Bjornevik      m     NOR    1-5 Aug 2023
# 3      AAS  Fredrik Bjornevik      m     NOR    1-5 Aug 2023
# 4      AAS  Fredrik Bjornevik      m     NOR    1-5 Aug 2023
#
#                         Competition Round          Location Apparatus  Rank  \
# 0            2023 Cottbus World Cup  qual  Cottbus, Germany        HB  39.0
# 1            2023 Cottbus World Cup  qual  Cottbus, Germany        PH  44.0
# 2  2023 FISU World University Games  qual    Chengdu, China        FX  54.0
# 3  2023 FISU World University Games  qual    Chengdu, China        HB  44.0
# 4  2023 FISU World University Games  qual    Chengdu, China        PB  54.0
#
#    D_Score  E_Score  Penalty   Score
# 0      4.6    6.700      NaN  11.300
# 1      4.4    7.800      NaN  12.200
# 2      4.0    8.566      NaN  12.566
# 3      4.6    8.166      NaN  12.766
# 4      4.4    8.066      NaN  12.466

# %%
men_HB = men_df.filter(axis='Apparatus', like='HB')
men_HB.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/gym2024data/submission/code/.venv/lib/python3.10/site-packages/pandas/core/generic.py in ?(cls, axis)
#     552             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     553         except KeyError:
# --> 554             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 'Apparatus'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_6865/253769563.py in ?()
# ----> 1 men_HB = men_df.filter(axis="Apparatus",like="HB")
#       2 men_HB.head()
#
# ~/gym2024data/submission/code/.venv/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, items, like, regex, axis)
#    5696             )
#    5697
#    5698         if axis is None:
#    5699             axis = self._info_axis_name
# -> 5700         labels = self._get_axis(axis)
#    5701
#    5702         if items is not None:
#    5703             name = self._get_axis_name(axis)
#
# ~/gym2024data/submission/code/.venv/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, axis)
#     562     @final
#     563     def _get_axis(self, axis: Axis) -> Index:
# --> 564         axis_number = self._get_axis_number(axis)
#     565         assert axis_number in {0, 1}
#     566         return self.index if axis_number == 0 else self.columns
#
# ~/gym2024data/submission/code/.venv/lib/python3.10/site-packages/pandas/core/generic.py in ?(cls, axis)
#     550     def _get_axis_number(cls, axis: Axis) -> AxisInt:
#     551         try:
#     552             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     553         except KeyError:
# --> 554             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# ValueError: No axis named Apparatus for object type DataFrame
